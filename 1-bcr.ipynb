# %%
import pandas as pd
import bar_chart_race as bcr
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
df = bcr.load_dataset('covid19_tutorial')
#bcr.bar_chart_race(df)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv")
df.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/31/21  6/1/21  6/2/21  6/3/21  \
# 0        0        0        0        0  ...    71838   72977   74026   75119
# 1        0        0        0        0  ...   132315  132337  132351  132360
# 2        0        0        0        0  ...   128913  129218  129640  129976
# 3        0        0        0        0  ...    13727   13729   13744   13752
# 4        0        0        0        0  ...    34551   34752   34960   35140
#
#    6/4/21  6/5/21  6/6/21  6/7/21  6/8/21  6/9/21
# ...

# %%
df.shape
# Out:
# (276, 509)

# %%
df[df["Country/Region"].isin(["Brazil"])]
# Out:
#    Province/State Country/Region     Lat     Long  1/22/20  1/23/20  1/24/20  \
# 30            NaN         Brazil -14.235 -51.9253        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...   5/31/21    6/1/21    6/2/21    6/3/21  \
# 30        0        0        0  ...  16545554  16624480  16720081  16803472
#
#       6/4/21    6/5/21    6/6/21    6/7/21    6/8/21    6/9/21
# 30  16841408  16907425  16947062  16984218  17037129  17122877
#
# [1 rows x 509 columns]

# %%
df_desire=df[df["Country/Region"].isin(["Bangladesh", "Pakistan", "India", 
                          "Iran", "US", "Italy", "Spain", "Brazil", 
                          "Uk", "China"])]
df_desire.head()
# Out:
#    Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 20            NaN     Bangladesh  23.6850   90.3563        0        0
# 30            NaN         Brazil -14.2350  -51.9253        0        0
# 58          Anhui          China  31.8257  117.2264        1        9
# 59        Beijing          China  40.1824  116.4142       14       22
# 60      Chongqing          China  30.0572  107.8740        6        9
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...   5/31/21    6/1/21    6/2/21  \
# 20        0        0        0        0  ...    800540    802305    804293
# 30        0        0        0        0  ...  16545554  16624480  16720081
# 58       15       39       60       70  ...      1004      1004      1004
# 59       36       41       68       80  ...      1059      1059      1060
# 60       27       57       75      110  ...       598       598       598
#
#       6/3/21    6/4/21    6/5/21    6/6/21    6/7/21    6/8/21    6/9/21
# ...

# %%
df_desire_melt=pd.melt(df_desire, id_vars=["Province/State", 
                                          "Country/Region", 
                                          "Lat", 
                                          "Long"], 
                      var_name="date", 
                      value_name="total_cases")
df_desire_melt.head()
# Out:
#   Province/State Country/Region      Lat      Long     date  total_cases
# 0            NaN     Bangladesh  23.6850   90.3563  1/22/20            0
# 1            NaN         Brazil -14.2350  -51.9253  1/22/20            0
# 2          Anhui          China  31.8257  117.2264  1/22/20            1
# 3        Beijing          China  40.1824  116.4142  1/22/20           14
# 4      Chongqing          China  30.0572  107.8740  1/22/20            6

# %%
df_desire_melt.drop(["Province/State", "Lat", "Long"], 
              inplace=True, 
              axis=1)
df_desire_melt.head()
# Out:
#   Country/Region     date  total_cases
# 0     Bangladesh  1/22/20            0
# 1         Brazil  1/22/20            0
# 2          China  1/22/20            1
# 3          China  1/22/20           14
# 4          China  1/22/20            6

# %%
df_desire_melt["date"]=pd.to_datetime(df_desire_melt.date)
df_desire_melt.head()
# Out:
#   Country/Region       date  total_cases
# 0     Bangladesh 2020-01-22            0
# 1         Brazil 2020-01-22            0
# 2          China 2020-01-22            1
# 3          China 2020-01-22           14
# 4          China 2020-01-22            6

# %%
df_desire_pivot=pd.pivot_table(df_desire_melt, columns="Country/Region", 
              values="total_cases", 
              index="date", aggfunc="sum")
df_desire_pivot.head()
# Out:
# Country/Region  Bangladesh  Brazil  China  India  Iran  Italy  Pakistan  \
# date
# 2020-01-22               0       0    548      0     0      0         0
# 2020-01-23               0       0    643      0     0      0         0
# 2020-01-24               0       0    920      0     0      0         0
# 2020-01-25               0       0   1406      0     0      0         0
# 2020-01-26               0       0   2075      0     0      0         0
#
# Country/Region  Spain  US
# date
# 2020-01-22          0   1
# 2020-01-23          0   1
# 2020-01-24          0   2
# 2020-01-25          0   2
# 2020-01-26          0   5

# %%
plt.fig
bcr.bar_chart_race(df_desire_pivot.iloc[-100:, :])
# Out:
# <div id='12631f50-8020-4328-8106-3ecc8e7e72e5'></div>
# C:\Users\HP-NPC\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\HP-NPC\anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# <video width="934" height="504" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
df_china=df[df["Country/Region"].isin(['China'])]\
.melt(id_vars=["Province/State", 
                                          "Country/Region", 
                                          "Lat", 
                                          "Long"], 
                      var_name="date", 
                      value_name="total_cases")
df_china.head()
# Out:
#   Province/State Country/Region      Lat      Long     date  total_cases
# 0          Anhui          China  31.8257  117.2264  1/22/20            1
# 1        Beijing          China  40.1824  116.4142  1/22/20           14
# 2      Chongqing          China  30.0572  107.8740  1/22/20            6
# 3         Fujian          China  26.0789  117.9874  1/22/20            1
# 4          Gansu          China  35.7518  104.2861  1/22/20            0

# %%
df_china["Province/State"].unique()
# Out:
# array(['Anhui', 'Beijing', 'Chongqing', 'Fujian', 'Gansu', 'Guangdong',
#        'Guangxi', 'Guizhou', 'Hainan', 'Hebei', 'Heilongjiang', 'Henan',
#        'Hong Kong', 'Hubei', 'Hunan', 'Inner Mongolia', 'Jiangsu',
#        'Jiangxi', 'Jilin', 'Liaoning', 'Macau', 'Ningxia', 'Qinghai',
#        'Shaanxi', 'Shandong', 'Shanghai', 'Shanxi', 'Sichuan', 'Tianjin',
#        'Tibet', 'Unknown', 'Xinjiang', 'Yunnan', 'Zhejiang'], dtype=object)

# %%
pd.DataFrame(df_china_gb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-06b06b59e823> in <module>
# ----> 1 pd.DataFrame(df_china_gb)
#
# NameError: name 'df_china_gb' is not defined

# %%
import numpy as np

# %%
def series_sumation(a,r,term):
    suma=0
    for n in np.arange(term)[1:]:
        suma=suma+a*r**(n-1)
    return suma

# %%
series_sumation(1,0.90,100000)
# Out:
# 9.999999999999993

# %%
np.sqrt(2)
# Out:
# 1.4142135623730951
