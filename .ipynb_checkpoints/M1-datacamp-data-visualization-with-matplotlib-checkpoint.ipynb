# %% [markdown]
# ### Import library

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Import dataset

# %%
df1=pd.read_csv('data/datacamp/seattle_weather.csv')
df2=pd.read_csv('data/datacamp/austin_weather.csv')

# %%
df1.iloc[:5, :5]
# Out:
#        STATION                 NAME  DATE  MLY-CLDD-BASE45  MLY-CLDD-BASE50
# 0  USC00456295  PALMER 3 ESE, WA US     1             13.0              1.0
# 1  USC00456295  PALMER 3 ESE, WA US     2             23.0              3.0
# 2  USC00456295  PALMER 3 ESE, WA US     3             50.0             11.0
# 3  USC00456295  PALMER 3 ESE, WA US     4            108.0             40.0
# 4  USC00456295  PALMER 3 ESE, WA US     5            255.0            130.0

# %%
df2.iloc[:5, :5]
# Out:
#        STATION                                           NAME  DATE  \
# 0  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
#
#    MLY-CLDD-BASE45  MLY-CLDD-BASE50
# 0              190              103
# 1              228              132
# 2              446              306
# 3              668              519
# 4              936              781

# %%
seattle_weather=df1.loc[:11, ["DATE","MLY-TAVG-NORMAL", "MLY-PRCP-NORMAL", 
                             "MLY-PRCP-25PCTL", "MLY-PRCP-75PCTL"]]
seattle_weather.rename(columns={'DATE': 'MONTH'}, inplace=True)
seattle_weather.tail()
# Out:
#     MONTH  MLY-TAVG-NORMAL  MLY-PRCP-NORMAL  MLY-PRCP-25PCTL  MLY-PRCP-75PCTL
# 7       8             63.5             2.56             1.28             3.41
# 8       9             58.9             3.95             2.56             5.75
# 9      10             50.7             7.29             5.35             9.36
# 10     11             42.9            12.58             8.43            16.26
# 11     12             37.7             9.85             8.33            11.64

# %%
austin_weather=df2.loc[:11, ["DATE","MLY-TAVG-NORMAL", "MLY-PRCP-NORMAL", 
                            "MLY-PRCP-25PCTL", "MLY-PRCP-75PCTL"]]
austin_weather.rename(columns={'DATE': 'MONTH'}, inplace=True)
austin_weather.tail()
# Out:
#     MONTH  MLY-TAVG-NORMAL  MLY-PRCP-NORMAL  MLY-PRCP-25PCTL  MLY-PRCP-75PCTL
# 7       8             83.7             2.03             0.74             2.58
# 8       9             77.8             2.54             0.77             4.06
# 9      10             69.0             4.24             1.57             6.50
# 10     11             58.4             2.94             1.04             3.78
# 11     12             50.4             2.21             0.51             2.96

# %% [markdown]
# ## Introduction to data visualization with Matplotlib

# %% [markdown]
# ### Introducing the pyplot interface

# %%
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# ### Adding data to axes

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(austin_weather.MONTH, austin_weather["MLY-TAVG-NORMAL"])

# %%
fig, ax = plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"])
ax.plot(austin_weather["MONTH"], austin_weather["MLY-TAVG-NORMAL"])
plt.show()

# %% [markdown]
# ## Customizing your plots

# %% [markdown]
# ### Customizing dat appearance

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o')

# %% [markdown]
# ### [Chossing marker](https://matplotlib.org/api/markers_api.html)

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='v')

# %% [markdown]
# ### Setting the linestyle

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o', linestyle='--')

# %% [markdown]
# ### Eliminiting lines with linestyle

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o', linestyle='None')

# %% [markdown]
# ### Choosing color

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o', linestyle='--', color='r')

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o', linestyle='--', color='r', markerfacecolor='b')

# %% [markdown]
# ### Customizing the axes label

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-TAVG-NORMAL"],
       marker='o', linestyle='--', color='r')

ax.set_xlabel("Time (months)")

ax.set_ylabel("Average temperature (Fahrenheit degrees)")

ax.set_title("Weather in Seattle")
# Out:
# Text(0.5, 1.0, 'Weather in Seattle')

# %% [markdown]
# ## Small multiples
# ### Adding data

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"],
    seattle_weather["MLY-PRCP-NORMAL"],
    color='b')
ax.set_xlabel("Time (months)")
ax.set_ylabel("Precipitation (inches)")
# Out:
# Text(0, 0.5, 'Precipitation (inches)')

# %% [markdown]
# ### Adding more data

# %%
fig, ax=plt.subplots()
ax.plot(seattle_weather["MONTH"],seattle_weather["MLY-PRCP-NORMAL"], 
        linestyle="-", color='m')

ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"],
        linestyle='--', color='b')

ax.plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
        linestyle='--', color='r')

# %% [markdown]
# ### Small multiples with `plt.subplots`

# %%
fig,ax=plt.subplots(3,2)

# %%
ax.shape
# Out:
# (3, 2)

# %%
fig,ax=plt.subplots(3,2)
ax[0, 0].plot(seattle_weather["MONTH"],
        seattle_weather["MLY-PRCP-NORMAL"], color='b')

# %% [markdown]
# ### Subplots with data

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], 
           color='b')

ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], 
           linestyle='--', color='b')

ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
           linestyle='--', color='b')


ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
           color='r')

ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"],
           linestyle='--', color='r')

ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"],
           linestyle='--', color='r')


ax[0].set_ylabel("Precipitation (inches)")
ax[1].set_ylabel("Precipitation (inches)")
ax[1].set_xlabel("Time (months)")
# Out:
# Text(0.5, 0, 'Time (months)')

# %% [markdown]
# ### Sharing the y axis range

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharey=True)
ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-NORMAL"], 
           color='b')

ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-25PCTL"], 
           linestyle='--', color='b')

ax[0].plot(seattle_weather["MONTH"], seattle_weather["MLY-PRCP-75PCTL"],
           linestyle='--', color='b')


ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-NORMAL"],
           color='r')

ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-25PCTL"],
           linestyle='--', color='r')

ax[1].plot(austin_weather["MONTH"], austin_weather["MLY-PRCP-75PCTL"],
           linestyle='--', color='r')


ax[0].set_ylabel("Precipitation (inches)")
ax[1].set_ylabel("Precipitation (inches)")
ax[1].set_xlabel("Time (months)")
# Out:
# Text(0.5, 0, 'Time (months)')
