# %%
#!pip install seaborn --upgrade

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.__version__
# Out:
# '0.11.1'

# %% [markdown]
# ### Scatter plot

# %%
height = [62, 64, 69, 75, 66,
            68, 65, 71, 76, 73]

weight = [120, 136, 148, 175, 137,
            165, 154, 172, 200, 187]
sns.scatterplot(x=height, y=weight)
# Out:
# <AxesSubplot:>

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### A scatter plot with hue

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Setting hue order

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="smoker", 
               hue_order=["No", "Yes"])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Specifying hue colors

# %%
hue_colors={'Yes':'m', 'No':'y'}
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="smoker",
               palette=hue_colors)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
hue_colors = {"Yes": "#808080", "No": "#00FF00"}
sns.scatterplot(x="total_bill", y="tip", data=tips, 
                hue="smoker",palette=hue_colors)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### Count plot

# %%
gender = ["Female", "Female",
            "Female", "Female",
            "Male", "Male", "Male",
            "Male", "Male", "Male"]
sns.countplot(gender)
# Out:
# C:\Users\HP-NPC\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='count'>

# %%
sns.countplot(x="smoker",data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x="smoker",hue='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
df=pd.read_csv("data/datacamp/countries-of-the-world.csv")
df.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
df.Region.unique()
# Out:
# array(['ASIA (EX. NEAR EAST)         ',
#        'EASTERN EUROPE                     ',
#        'NORTHERN AFRICA                    ',
#        'OCEANIA                            ',
#        'WESTERN EUROPE                     ',
#        'SUB-SAHARAN AFRICA                 ', 'LATIN AMER. & CARIB    ',
#        'C.W. OF IND. STATES ', 'NEAR EAST                          ',
#        'NORTHERN AMERICA                   ',
#        'BALTICS                            '], dtype=object)

# %%
df["Region"]=df.Region.str.strip()

# %%
df.Region.unique()
# Out:
# array(['ASIA (EX. NEAR EAST)', 'EASTERN EUROPE', 'NORTHERN AFRICA',
#        'OCEANIA', 'WESTERN EUROPE', 'SUB-SAHARAN AFRICA',
#        'LATIN AMER. & CARIB', 'C.W. OF IND. STATES', 'NEAR EAST',
#        'NORTHERN AMERICA', 'BALTICS'], dtype=object)

# %%
sns.countplot(y='Region', data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Region'>

# %% [markdown]
# ### Making a count plot with a DataFrame

# %%
young=pd.read_csv("data/datacamp/young-people-survey-responses.csv")
young.head(3)
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances   Age  Siblings  \
# 0         3.0              4.0  few hours a day       3.0  20.0       1.0
# 1         2.0              2.0  few hours a day       3.0  19.0       2.0
# 2         5.0              3.0  few hours a day       2.0  20.0       2.0
#
#    Gender Village - town
# 0  female        village
# 1  female           city
# 2  female           city

# %%
young.columns
# Out:
# Index(['Unnamed: 0', 'Music', 'Techno', 'Movies', 'History', 'Mathematics',
#        'Pets', 'Spiders', 'Loneliness', 'Parents' advice', 'Internet usage',
#        'Finances', 'Age', 'Siblings', 'Gender', 'Village - town'],
#       dtype='object')

# %%
sns.countplot(x="Spiders", data=young)
# Out:
# <AxesSubplot:xlabel='Spiders', ylabel='count'>

# %%
sns.countplot(y='Spiders', data=young)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Spiders'>

# %% [markdown]
# ### Introducing `relplot()`

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter")

# %% [markdown]
# ### Subplots in columns

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter",
        col="smoker")

# %% [markdown]
# ### Subplots in rows

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter",
        row="smoker")

# %% [markdown]
# ### Subplots in rows and columns

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter",
        col="smoker",
        row="time")

# %% [markdown]
# ### Wrapping columns

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter",
        col="day",
        col_wrap=2)

# %% [markdown]
# ### Ordering columns

# %%
sns.relplot(x="total_bill",
        y="tip",
        data=tips,
        kind="scatter",
        col="day",
        col_wrap=2,
        col_order=["Thur",
                    "Fri",
                    "Sat",
                    "Sun"])

# %% [markdown]
# ### Hue and scatter plots

# %%
student_data=pd.read_csv("data/datacamp/student-alcohol-consumption.csv")
student_data.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'famsize', 'Pstatus', 'Medu',
#        'Fedu', 'traveltime', 'failures', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3', 'location', 'study_time'],
#       dtype='object')

# %%
sns.scatterplot(x='absences', y='G3', hue='location', data=student_data)
# Out:
# <AxesSubplot:xlabel='absences', ylabel='G3'>

# %% [markdown]
# ### Hue and count plots

# %%
 #Create a dictionary mapping subgroup values to colors
palette_colors = {'Rural': "green", 'Urban': "blue"}

# Create a count plot of school with location subgroups
sns.countplot(x='school', hue='location', palette=palette_colors, 
              data=student_data)
# Out:
# <AxesSubplot:xlabel='school', ylabel='count'>

# %% [markdown]
# ### Creating subplots with col and row

# %%
sns.relplot(x="absences", y="G3", 
                data=student_data, kind='scatter')

# %%
#Change to make subplots based on study time
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", col='study_time')

# %%
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3", 
            data=student_data,
            kind="scatter", 
            row="study_time")

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x='G1', y='G3', data=student_data, kind='scatter')

# %%
# Adjust to add subplots based on school support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", col='schoolsup', col_order=['yes', 'no'])

# %%
# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3", 
            data=student_data,
            kind="scatter", 
            col="schoolsup",
            col_order=["yes", "no"], row='famsup', row_order=['yes', 'no'])

# %% [markdown]
# ### Changing the size of scatter plot points

# %%
mpg=pd.read_csv("data/datacamp/mpg.csv")
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
# Create scatter plot of horsepower vs. mpg
sns.relplot(x='horsepower', y='mpg', size='cylinders', data=mpg, 
            kind='scatter')

# %%
# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower", y="mpg", 
            data=mpg, kind="scatter", 
            size="cylinders", hue='cylinders')

# %% [markdown]
# ### Changing the hue of scatter plot point

# %%
# Create scatter plot of acceleration vs. mpg
sns.relplot(x='acceleration', y='mpg', data=mpg, 
            kind='scatter', hue='origin')

# %% [markdown]
# ### Changing the style of scatter plot point

# %%
# Create scatter plot of acceleration vs. mpg
sns.relplot(x='acceleration', y='mpg', data=mpg, kind='scatter',
           hue='origin', style='origin')

# %% [markdown]
# ### Interpreting line plots

# %%
# Create line plot
sns.relplot(x='model_year', y='mpg', data=mpg, kind='line')

# %% [markdown]
# ### Visualizing standard deviation with line plots

# %%
sns.relplot(x="model_year", y="mpg",
            data=mpg, kind="line", ci='sd')

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x="model_year", y="horsepower",
            data=mpg, kind="line", ci=None)

# %%
# Change to create subgroups for country of origin
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, hue='origin', style='origin')

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year", y="horsepower", 
            data=mpg, kind="line", 
            ci=None, style="origin", 
            hue="origin", markers=True, dashes=False)

# %% [markdown]
# ### Bar plots
# Displays mean of quantitative variable per category

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar")

# %% [markdown]
# ### Turnint off confidence intervals

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", ci=None)

# %% [markdown]
# ### Changing the orientation

# %%
sns.catplot(x="total_bill", y="day", data=tips, kind="bar", ci=None)

# %% [markdown]
# ### How to create box plot

# %%
sns.catplot(x="time", y="total_bill", data=tips, kind="box")

# %% [markdown]
# ### Change the order of catagories

# %%
sns.catplot(x="time", y="total_bill", data=tips, 
            kind="box", 
            order=['Dinner', "Lunch"])

# %% [markdown]
# ### Omitting the outlier using `sym`

# %%
sns.catplot(x="time", y="total_bill", data=tips, 
            kind="box", 
            order=['Dinner', "Lunch"],
           sym="")

# %% [markdown]
# ### Changing the whisker using the `whis`

# %%
sns.catplot(x="time", y="total_bill", data=tips,
           kind="box",
           whis=2)
#default whis is 1.5*IQR

# %%
sns.catplot(x="time", y="total_bill", data=tips,
           kind="box",
           whis=[5,95])
#percentile 5 to 95

# %%
sns.catplot(x="time", y="total_bill", data=tips,
           kind="box",
           whis=[0,100])

# %% [markdown]
# ### Creating a point plot

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, kind="point")

# %%
sns.catplot(x='sex', y="G3", data=student_data,
           kind="point", hue="location")

# %% [markdown]
# ### Disconnecting the points

# %%
sns.catplot(x='sex', y="G3", data=student_data,
           kind="point", hue="location", join=False)

# %% [markdown]
# ### Displaying the median

# %%
from numpy import median
sns.catplot(x="smoker", y="total_bill", data=tips, 
            kind="point", estimator=median)

# %% [markdown]
# ### Customizing the confidence intervals

# %%
sns.catplot(x="smoker", y="total_bill", data=tips, 
            kind="point", capsize=.2)
